# %%
import pandas as pd
df = pd.read_csv('tuition_fee.csv')
import matplotlib.pyplot as plt
df = df.drop("學校統計處代碼", axis='columns')
df = df.rename(columns={"日間學制學士班學雜費收費基準-醫學系": "Department of Medicine"})
df = df.rename(columns={"日間學制學士班學雜費收費基準-牙醫學系": "Department of Dental Medicine"})
df = df.rename(columns={"日間學制學士班學雜費收費基準-醫學院": "College of Medicine"})
df = df.rename(columns={"日間學制學士班學雜費收費基準-工學院": "College of Engineering"})
df = df.rename(columns={"日間學制學士班學雜費收費基準-理農學院": "College of Science and Agriculture"})
df = df.rename(columns={"日間學制學士班學雜費收費基準-商學院": "College of Business"})
df = df.rename(columns={"日間學制學士班學雜費收費基準-文法學院": "College of Law and Liberal Arts"})
df = df.rename(columns={"日間學制學士班學雜費收費基準-其他": "Others"})
df = df.rename(columns={"日間學制副學士學雜費收費基準(五專後2年、二專)-工業類": "Associate Degree of Industry"})
df = df.rename(columns={"日間學制副學士學雜費收費基準(五專後2年、二專)-商管類": "Associate Degree of Business and Management"})
df = df.rename(columns={"日間學制副學士學雜費收費基準(五專後2年、二專)-醫護類": "Associate Degree of Medical Care"})
df = df.rename(columns={"日間學制副學士學雜費收費基準(五專後2年、二專)-其他": "Associate Degree of Others"})
#Bachelor of ---
#Associate degree
df.tail(50)
# Out:
#      學年度 設立別    學校類別                 學校名稱 Department of Medicine  \
# 724  110  私立    技專校院               東南科技大學                      0
# 725  110  私立    技專校院             德明財經科技大學                      0
# 726  110  私立    一般大學         明道學校財團法人明道大學                      0
# 727  110  私立    技專校院               南開科技大學                      0
# 728  110  私立    技專校院       中華學校財團法人中華科技大學                      0
# 729  110  私立    技專校院               僑光科技大學                      0
# 730  110  私立    技專校院       廣亞學校財團法人育達科技大學                      0
# 731  110  私立    技專校院       美和學校財團法人美和科技大學                      0
# 732  110  私立    技專校院               吳鳳科技大學                      0
# 733  110  私立    技專校院       環球學校財團法人環球科技大學                      0
# 734  110  私立    一般大學     台灣首府學校財團法人台灣首府大學                      0
# 735  110  私立    技專校院       中州學校財團法人中州科技大學                      0
# 736  110  私立    技專校院       修平學校財團法人修平科技大學                      0
# ...
